# %%
import os
import sys
import math as m
import pandas as pd
import csv
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from scipy import stats

plt.style.use('ggplot')

from sqlalchemy import *
from sqlalchemy import create_engine
engine = create_engine('postgresql://wenfei:xj32MYNt3q4jaH@52.23.144.14:5432/stl')
# engine = create_engine('postgresql://mike:pbkqa0pfjd@52.23.144.14:5432/stl')

# %%
## Create inspector for metadata
inspector = inspect(engine)
print inspector.get_table_names()
# Out:
# [u'fangprojcode', u'spatial_ref_sys', u'fanglisting', u'fanglistingstatus', u'apartmentsforrent', u'apartmentsforrentrecords', u'apartmentsforsale', u'apartmentsforsalerecords', u'apartmentsforsublet', u'cd_residentialgrids_nearest_10_dianping_grocery_poi_table', u'apartmentsforsubletrecords', u'roomforshortrental', u'roomforshortrentalrecords', u'dianpingbusiness_old', u'fanglisting_geom', u'shanghai_fishnet_quarterkm_WGS', u'fanglisting_1203_1210', u'fanglisting_1203_1210_valid', u'fanglisting_1203_1210_psm_community', u'cd_residentialgrids_nearest_5_dianping_malls_poi_table', u'fanglisting_nov_uniq', u'chengdu_fishnet_quarterkm_WGS', u'fanglisting_nov_dups_uniq', u'fanglisting_nov_dup_pairs_old', u'fanglisting_nov_dup_pairs', u'fanglisting_nov_dup', u'fangtransaction', u'fanglistingcommunity', u'fangprojcodecoords', u'fang_listing_txn_community_t', u'amap_poi_search_fishnet', u'amap_poi_search_status', u'amap_poi_info', u'amap_poi_info_extended_raw', u'dianpingbusiness', u'baidu_p
# ...

# %%
## Import resi grids

CD_Grids = pd.read_sql_query('SELECT * FROM cd_residentialgrids_selected',con=engine)

# %%
## Show distribution of distances for Medical
grids_medical = pd.read_sql_query('SELECT * FROM cd_residentialgrids_nearest_2_dianping_medical_poi_distance',con=engine)


data = sorted(grids_medical.min_distance)

# plt.scatter(range(0,len(data),1), data,marker ='o', s=30, linewidth = 0.15, color='darkblue', facecolor="none",alpha=0.8)
plt.hist(data,bins=100,color='darkblue')
plt.plot((1700,1700),(0,1000),'r--')
# plt.plot((0, 1000), (13000, 13000), 'r--')
# plt.xlabel('')
plt.ylabel('Frequency')
plt.xlabel('Distance in Meters')
plt.title('Distribution of Nearest Hospital Distances, Threshold = 1.7km')
plt.tight_layout()
plt.show()

# %%
## Show distribution of distances for University
grids_university = pd.read_sql_query('SELECT * FROM cd_residentialgrids_nearest_1_dianping_university_poi_distance',con=engine)


data = sorted(grids_university.min_distance)

# plt.scatter(range(0,len(data),1), data,marker ='o', s=30, linewidth = 0.15, color='darkblue', facecolor="none",alpha=0.8)
plt.hist(data,bins=100,color='darkblue')
plt.plot((2500,2500),(0,1000),'r--')
# plt.plot((0, 20000), (6500, 6500), 'r--')
# plt.xlabel('')
plt.ylabel('Frequency')
plt.xlabel('Distance in Meters')
plt.title('Distribution of Nearest University Distances, Threshold = 2.5km')
plt.tight_layout()
plt.show()

# %%
## Show distribution of distances for Malls
grids_malls = pd.read_sql_query('SELECT * FROM cd_residentialgrids_nearest_1_dianping_malls_poi_distance',con=engine)


data = sorted(grids_malls.min_distance)

# plt.scatter(range(0,len(data),1), data,marker ='o', s=30, linewidth = 0.15, color='darkblue', facecolor="none",alpha=0.8)
plt.hist(data,bins=100,color='darkblue')
plt.plot((2500,2500),(0,1000),'r--')
# plt.plot((0, 20000), (5000, 5000), 'r--')
# plt.xlabel('')
plt.ylabel('Frequency')
plt.xlabel('Distance in Meters')
plt.title('Distribution of Nearest Malls Distances, Threshold = 2.5km')
plt.tight_layout()
plt.show()

# %%
## Show distribution of distances for Groceries
grids_grocery = pd.read_sql_query('SELECT * FROM cd_residentialgrids_nearest_2_dianping_grocery_poi_distance',con=engine)


data = sorted(grids_grocery.min_distance)

# plt.scatter(range(0,len(data),1), data,marker ='o', s=30, linewidth = 0.15, color='darkblue', facecolor="none",alpha=0.8)
plt.hist(data,color='darkblue',bins = 100)
plt.plot((1500,1500),(0,1000),'r--')
# plt.plot((0, 20000), (3500, 3500), 'r--')
# plt.xlabel('')
plt.ylabel('Frequency')
plt.xlabel('Distance in Meters')
plt.title('Distribution of Nearest Grocery Store Distances, Threshold = 1.5km')
plt.tight_layout()
plt.show()

# %%
## Show distribution of distances for Schools
grids_schools = pd.read_sql_query('SELECT * FROM cd_residentialgrids_nearest_2_dianping_educational_poi_distance',con=engine)


data = sorted(grids_schools.min_distance)

# plt.scatter(range(0,len(data),1), data,marker ='o', s=30, linewidth = 0.15, color='darkblue', facecolor="none",alpha=0.8)
plt.hist(data,color='darkblue',bins = 100)
plt.plot((2000,2000),(0,1000),'r--')
# plt.plot((0, 20000), (5000, 5000), 'r--')
# plt.xlabel('')

plt.ylabel('Frequency')
plt.xlabel('Distance in Meters')
plt.title('Distribution of Nearest Schools Distances, Threshold = 2km')
plt.tight_layout()
plt.show()

# %%
## Show distribution of distances for Banks
grids_banks = pd.read_sql_query('SELECT * FROM cd_residentialgrids_nearest_2_dianping_banks_poi_distance',con=engine)


data = sorted(grids_banks.min_distance)

# plt.scatter(range(0,len(data),1), data,marker ='o', s=30, linewidth = 0.15, color='darkblue', facecolor="none",alpha=0.8)
plt.hist(data,color='darkblue',bins = 100)
plt.plot((2000,2000),(0,1000),'r--')
# plt.plot((0, 20000), (4000, 4000), 'r--')
# plt.xlabel('')
plt.ylabel('Frequency')
plt.xlabel('Distance in Meters')
plt.title('Distribution of Nearest Banks Distances, Threshold = 2km')
plt.tight_layout()
plt.show()

# %%
## Show distribution of distances for Salons
grids_salons = pd.read_sql_query('SELECT * FROM cd_residentialgrids_nearest_1_dianping_beauty_poi_distance',con=engine)


data = sorted(grids_salons.min_distance)

# plt.scatter(range(0,len(data),1), data,marker ='o', s=30, linewidth = 0.15, color='darkblue', facecolor="none",alpha=0.8)
plt.hist(data,color='darkblue',bins = 100)
plt.plot((700,700),(0,1700),'r--')
# plt.plot((0, 20000), (4000, 4000), 'r--')
# plt.xlabel('')
plt.ylabel('Frequency')
plt.xlabel('Distance in Meters')
plt.title('Distribution of Nearest Salons Distances, Threshold = 700m')
plt.tight_layout()
plt.show()

# %%
## Show distribution of distances for Restaurants
grids_restaurants = pd.read_sql_query('SELECT * FROM cd_residentialgrids_nearest_5_dianping_restaurants_poi_distance',con=engine)


data = sorted(grids_restaurants.min_distance)

# plt.scatter(range(0,len(data),1), data,marker ='o', s=30, linewidth = 0.15, color='darkblue', facecolor="none",alpha=0.8)
plt.hist(data,color='darkblue',bins = 100)
plt.plot((200,200),(0,1700),'r--')
# plt.plot((0, 20000), (4000, 4000), 'r--')
# plt.xlabel('')
plt.ylabel('Frequency')
plt.xlabel('Distance in Meters')
plt.title('Distribution of Nearest Restaurants Distances, Threshold = 200m')
plt.tight_layout()
plt.show()

# %%
## Clean up grid dataset
CD_Grids_new = CD_Grids.drop(['FID_1_1','ID','Count_1','X_MIN','X_MAX','Y_MIN','Y_MAX','Sum_FISH_1','Sum_GCJ0_2','Sum_GCJ0_3','Sum_FISHNE','Sum_GCJ02_','Sum_GCJ0_1','the_geom'],1)
CD_Grids_new.columns = ['gid','FID','Count','Resi','Resi_neighbor','Neighbor_FID']
CD_Grids_new.head()

# %%
## Find cell GIDs for those under the threshold 

thresholds_cat = ['medical','university','malls','grocery','schools','banks','salons','restaurants']
thresholds = [1700,2500,2500,1500,2000,2000,700,200] 

# oldcolumns =  CD_Grids_new.columns.values.tolist()

# CD_Grids_new_test= CD_Grids_new.reindex(columns=list(oldcolumns.extend(thresholds_cat)),fill_value=0)  

for eachlimit,limitcat in zip(thresholds,thresholds_cat): ## Mark all those within the limit
    CD_Grids_new[limitcat] = 0
    CD_Grids_new.ix[CD_Grids_new['gid'].isin(eval("grids_%s"%limitcat)[eval("grids_%s"%limitcat).min_distance <=eachlimit].gid.values),limitcat]=1
#     CD_Grids_new.ix[CD_Grids_new['gid'].isin(grids_medical[grids_medical.min_distance <=eachlimit].gid.values)],limitcat]=1
    
# df.ix[df.A==0, 'B'] 
#     underthreshold =CD_Grids[CD_Grids['gid'].isin(grids_medical[grids_medical.min_distance <=eachlimit].gid.values)].gid

# %%
CD_Grids_new.to_csv('/Users/wenfeixu/Dropbox (MIT)/MIT/CDDL/STL_WeChatProject/0_data/working_wenfei/CD_Grids_results_jan31.csv',encoding='utf-8')

# %%
CD_Grids_new[CD_Grids_new.medical ==1]
# Out:
#          gid    FID  Count  Resi  Resi_neighbor  \
# 2049   10160  10159      1     1              1
# 2050   10161  10160      0     0              1
# 2051   10162  10161      0     0              1
# 2052   10163  10162      0     0              1
# 2053   10164  10163      1     1              1
# 2117   10415  10414      3     1              1
# 2118   10416  10415      0     0              1
# 2119   10417  10416      1     1              1
# 2120   10418  10417      0     0              1
# 2121   10419  10418      0     0              1
# 2122   10420  10419      0     0              1
# 2123   10421  10420      0     0              1
# 2124   10422  10421      0     0              1
# 2202   10670  10669      0     0              1
# 2203   10671  10670      6     1              1
# 2204   10672  10671      0     0              1
# 2205   10673  10672      1     1              1
# 2206   10674  10673      0     0              1
# ...
